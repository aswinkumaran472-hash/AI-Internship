# %% [markdown]
# # Day 7: LangChain Basics
#
# ## Objective
#
# Learn LangChain fundamentals including prompt templates, chains, LCEL, and multiple LLM providers.

# %% [markdown]
# ## What is LangChain?
#
# LangChain is a framework used to build LLM applications.

# %% [markdown]
# ## Features
#
# - Prompt Templates
# - Chains
# - Memory
# - Agents
# - Retrieval

# %% [markdown]
# ## Prompt Templates
#
# Prompt Templates help create reusable prompts.

# %%
template = "Explain {topic}"

print(template)
# Out:
# Explain {topic}

# %% [markdown]
# ## Chat Prompt Template
#
# Used for chat-based applications.

# %% [markdown]
# ## Chains
#
# Chains connect multiple operations together.

# %%
input_text = "AI"

print("Processing:", input_text)
# Out:
# Processing: AI

# %% [markdown]
# ## LCEL
#
# LCEL stands for LangChain Expression Language.
#
# Used to build efficient pipelines.

# %% [markdown]
# ## OpenAI Provider

# %%
provider = "OpenAI"

print(provider)
# Out:
# OpenAI

# %% [markdown]
# ## Gemini Provider

# %%
provider = "Gemini"

print(provider)
# Out:
# Gemini

# %% [markdown]
# ## Claude Provider

# %% [markdown]
# ## Provider Comparison
#
# OpenAI → GPT Models
#
# Gemini → Google Models
#
# Claude → Anthropic Models

# %% [markdown]
# ## Applications
#
# - Chatbots
# - RAG Systems
# - AI Assistants
# - Search Systems

# %% [markdown]
# ## Conclusion
#
# In this notebook, we learned:
#
# - LangChain
# - Prompt Templates
# - Chat Templates
# - Chains
# - LCEL
# - OpenAI
# - Gemini
# - Claude
