# %% [markdown]
# # Day 3: Embeddings and Semantic Search
#
# ## Objective
#
# Learn how text embeddings work and how semantic search finds similar meanings instead of exact keyword matches.

# %% [markdown]
# ## What are Embeddings?
#
# Embeddings are numerical vector representations of text.
#
# They convert words, sentences, or documents into numbers that AI models can understand.

# %% [markdown]
# ## Why Embeddings?
#
# Traditional Search:
# - Matches keywords
#
# Semantic Search:
# - Matches meaning
#
# Example:
#
# Sentence 1:
# "I love learning AI"
#
# Sentence 2:
# "I enjoy studying artificial intelligence"
#
# Both have similar meanings even though words differ.

# %% [markdown]
# sentence1 = "I love learning AI"
# sentence2 = "I enjoy studying artificial intelligence"
#
# print(sentence1)
# print(sentence2)

# %% [markdown]
# ## What is Semantic Search?
#
# Semantic Search retrieves information based on meaning rather than exact words.

# %% [markdown]
# ## Embedding Models
#
# Popular Embedding Models:
#
# 1. OpenAI Embeddings
# 2. Sentence Transformers
# 3. BERT Embeddings
# 4. Gemini Embeddings

# %% [markdown]
# ## Vector Representation
#
# Text is converted into vectors.
#
# Example:
#
# Hello -> [0.12, 0.55, 0.91]
#
# AI -> [0.67, 0.21, 0.45]

# %%
vector1 = [0.12, 0.55, 0.91]
vector2 = [0.67, 0.21, 0.45]

print(vector1)
print(vector2)
# Out:
# [0.12, 0.55, 0.91]
# [0.67, 0.21, 0.45]

# %% [markdown]
# ## Cosine Similarity
#
# Cosine Similarity measures how similar two vectors are.
#
# Range:
# -1 to 1
#
# 1 = Highly Similar
# 0 = No Similarity

# %%
from math import sqrt

A = [1, 2, 3]
B = [1, 2, 4]

dot = sum(a*b for a,b in zip(A,B))

magA = sqrt(sum(a*a for a in A))
magB = sqrt(sum(b*b for b in B))

similarity = dot/(magA*magB)

print("Cosine Similarity:", similarity)
# Out:
# Cosine Similarity: 0.9914601339836675

# %% [markdown]
# ## Example Dataset

# %%
documents = [
    "I love machine learning",
    "Artificial intelligence is amazing",
    "Python is a programming language",
    "Deep learning uses neural networks"
]

for doc in documents:
    print(doc)
# Out:
# I love machine learning
# Artificial intelligence is amazing
# Python is a programming language
# Deep learning uses neural networks

# %% [markdown]
# ## Simple Semantic Search Logic

# %%
query = "AI and machine learning"

documents = [
    "I love machine learning",
    "Artificial intelligence is amazing",
    "Python is a programming language"
]

print("Query:", query)

for doc in documents:
    print("Document:", doc)
# Out:
# Query: AI and machine learning
# Document: I love machine learning
# Document: Artificial intelligence is amazing
# Document: Python is a programming language

# %% [markdown]
# ## Real World Applications
#
# 1. Chatbots
# 2. Recommendation Systems
# 3. Search Engines
# 4. Question Answering
# 5. Document Retrieval

# %% [markdown]
# ## Vector Databases
#
# Popular Vector Databases:
#
# 1. Pinecone
# 2. ChromaDB
# 3. FAISS
# 4. Weaviate
#
# Used to store embeddings efficiently.

# %% [markdown]
# ## Advantages of Semantic Search
#
# - Understands meaning
# - Better search results
# - Works with synonyms
# - Improves user experience

# %% [markdown]
# ## Mini Project
#
# Semantic Search for Course Recommendations
#
# Query:
# "Learn AI"
#
# Documents:
# - Machine Learning Course
# - Python Programming Course
# - Data Science Course
#
# Goal:
# Find the most relevant course based on meaning.

# %%
courses = [
    "Machine Learning Course",
    "Python Programming Course",
    "Data Science Course"
]

query = "Learn AI"

print("Query:", query)

for course in courses:
    print(course)
# Out:
# Query: Learn AI
# Machine Learning Course
# Python Programming Course
# Data Science Course

# %% [markdown]
# ## Conclusion
#
# In this notebook, we learned:
#
# - Embeddings
# - Semantic Search
# - Vector Representation
# - Cosine Similarity
# - Vector Databases
# - Real World Applications
