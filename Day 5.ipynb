# %% [markdown]
# # Day 5: LLM Behaviour Basics
#
# ## Objective
# To understand how Large Language Models (LLMs) behave and generate responses.

# %% [markdown]
# ## What is an LLM?
#
# LLM stands for Large Language Model.
#
# Examples:
# - ChatGPT
# - Gemini
# - Claude
# - LLaMA

# %% [markdown]
# ## What is an LLM?
#
# LLM stands for Large Language Model.
#
# Examples:
# - ChatGPT
# - Gemini
# - Claude
# - LLaMA

# %% [markdown]
# ## How LLMs Work
#
# Input Text
#
# ↓
#
# Tokenization
#
# ↓
#
# Model Processing
#
# ↓
#
# Prediction
#
# ↓
#
# Generated Output

# %% [markdown]
# ## Tokens
#
# LLMs process text as tokens.
#
# Example:
#
# Hello World
#
# May become:
#
# ["Hello", "World"]

# %%
sentence = "Hello World"
tokens = sentence.split()

print(tokens)
# Out:
# ['Hello', 'World']

# %%
sentence = "Hello World"
tokens = sentence.split()

print(tokens)
# Out:
# ['Hello', 'World']

# %% [markdown]
# ## Context Window
#
# Context Window is the amount of information an LLM can remember during a conversation.

# %% [markdown]
# ## Temperature
#
# Temperature controls randomness.
#
# Low Temperature:
# More accurate
#
# High Temperature:
# More creative

# %% [markdown]
# ## Temperature
#
# Temperature controls randomness.
#
# Low Temperature:
# More accurate
#
# High Temperature:
# More creative

# %%
temperature = 0.2

print("Temperature:", temperature)
# Out:
# Temperature: 0.2

# %%
temperature = 0.2

print("Temperature:", temperature)
# Out:
# Temperature: 0.2

# %%
top_p = 0.9

print("Top P:", top_p)
# Out:
# Top P: 0.9

# %% [markdown]
# ## Hallucination
#
# Hallucination occurs when an LLM generates incorrect information confidently.

# %% [markdown]
# ## System Prompt
#
# Defines model behavior.
#
# Example:
#
# "You are a helpful AI assistant."

# %% [markdown]
# ## User Prompt
#
# Questions given by users.

# %%
prompt = "What is Artificial Intelligence?"

print(prompt)
# Out:
# What is Artificial Intelligence?

# %% [markdown]
# ## Assistant Response
#
# Generated answer returned by the model.

# %% [markdown]
# ## Factors Affecting Output
#
# 1. Prompt Quality
# 2. Context
# 3. Temperature
# 4. Model Size

# %% [markdown]
# ## Applications
#
# - Chatbots
# - Content Generation
# - Translation
# - Coding Assistants

# %% [markdown]
# ## Conclusion
#
# In this notebook, we learned:
# - Tokens
# - Context Window
# - Temperature
# - Top-P
# - Hallucination
# - Prompts
# - LLM Behavior
