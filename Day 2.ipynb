# %% [markdown]
# # Day 2: APIs and JSON
#
# ## Objective
# Learn how APIs work, how to send requests, receive responses, and process JSON data using Python.

# %% [markdown]
# ## What is an API?
#
# API (Application Programming Interface) allows two software applications to communicate with each other.
#
# Examples:
# - Weather Apps
# - Google Maps
# - Payment Gateways
# - Social Media Platforms

# %% [markdown]
# ## Types of APIs
#
# 1. REST API
# 2. SOAP API
# 3. GraphQL API
#
# REST APIs are the most commonly used APIs in modern applications.

# %% [markdown]
# ## HTTP Methods
#
# GET    -> Retrieve Data
# POST   -> Create Data
# PUT    -> Update Data
# DELETE -> Remove Data

# %%
import requests
print(requests.__version__)
# Out:
# 2.32.4

# %%
import requests

# %% [markdown]
# ## GET Request Example

# %%
import requests

url = "https://jsonplaceholder.typicode.com/posts/1"

response = requests.get(url)

print(response.status_code)
print(response.text)
# Out:
# 200
# {
#   "userId": 1,
#   "id": 1,
#   "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#   "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
# }

# %% [markdown]
# ## HTTP Status Codes
#
# 200 - Success
# 201 - Created
# 400 - Bad Request
# 401 - Unauthorized
# 404 - Not Found
# 500 - Internal Server Error

# %% [markdown]
# ## JSON
#
# JSON stands for JavaScript Object Notation.
#
# Used to exchange data between client and server.

# %%
{
  "name":"Rithish",
  "age":19
}
# Out:
# {'name': 'Rithish', 'age': 19}

# %%
data = response.json()

print(data)
# Out:
# {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}

# %%
print(data["title"])
print(data["body"])
# Out:
# sunt aut facere repellat provident occaecati excepturi optio reprehenderit
# quia et suscipit
# suscipit recusandae consequuntur expedita et cum
# reprehenderit molestiae ut ut quas totam
# nostrum rerum est autem sunt rem eveniet architecto

# %%
response = requests.get(
    "https://jsonplaceholder.typicode.com/posts"
)

posts = response.json()

for post in posts[:5]:
    print(post["title"])
# Out:
# sunt aut facere repellat provident occaecati excepturi optio reprehenderit
# qui est esse
# ea molestias quasi exercitationem repellat qui ipsa sit aut
# eum et est occaecati
# nesciunt quas odio

# %% [markdown]
# ## POST Request Example

# %%
new_post = {
    "title":"API Learning",
    "body":"Learning JSON",
    "userId":1
}

response = requests.post(
    "https://jsonplaceholder.typicode.com/posts",
    json=new_post
)

print(response.status_code)
print(response.json())
# Out:
# 201
# {'title': 'API Learning', 'body': 'Learning JSON', 'userId': 1, 'id': 101}

# %%
headers = {
    "User-Agent":"Python"
}

response = requests.get(
    "https://jsonplaceholder.typicode.com/posts/1",
    headers=headers
)

print(response.status_code)
# Out:
# 200

# %%
params = {
    "userId":1
}

response = requests.get(
    "https://jsonplaceholder.typicode.com/posts",
    params=params
)

print(response.url)
print(response.json()[:2])
# Out:
# https://jsonplaceholder.typicode.com/posts?userId=1
# [{'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}, {'userId': 1, 'id': 2, 'title': 'qui est esse', 'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'}]

# %% [markdown]
# try:
#     response = requests.get(
#         "https://jsonplaceholder.typicode.com/posts/1"
#     )
#
#     response.raise_for_status()
#
#     print("Success")
#
# except requests.exceptions.RequestException as e:
#     print("Error:",e)

# %% [markdown]
# ## Environment Variables
#
# Sensitive information such as API Keys should not be hardcoded.
#
# Use environment variables instead.

# %%
import os

api_key = os.getenv("API_KEY")

print(api_key)
# Out:
# None

# %% [markdown]
# ## Mini Project: User Information Fetcher

# %%
response = requests.get(
    "https://jsonplaceholder.typicode.com/users/1"
)

user = response.json()

print("Name :", user["name"])
print("Email:", user["email"])
print("City :", user["address"]["city"])
# Out:
# Name : Leanne Graham
# Email: Sincere@april.biz
# City : Gwenborough

# %% [markdown]
# ## Conclusion
#
# In this notebook, we learned:
# - APIs
# - HTTP Methods
# - GET Requests
# - POST Requests
# - JSON
# - Status Codes
# - Error Handling
# - Environment Variables
